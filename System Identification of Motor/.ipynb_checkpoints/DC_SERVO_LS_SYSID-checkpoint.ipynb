# %% [markdown]
# ## CONTINUOUS DC SERVO MODEL DISCOVERY

# %%
# Importing necessary Libraries

import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import sklearn.metrics as skm

# %%
data = scipy.io.loadmat("/home/aman/ACL/Servo-Motor-System-Identification/Data/Training_Set.mat")

# %%
class motor_param:
    def  __init__(self, PW, RPM):
        self.Pulse_Width = PW 
        self.Motor_RPM = RPM

# %%
anti_clock = motor_param(data["Training_set"][0][0][0][0][0][0], data["Training_set"][0][0][0][0][0][1])

# %%
clock = motor_param(data["Training_set"][0][0][1][0][0][0], data["Training_set"][0][0][1][0][0][1])

# %%
plt.plot(anti_clock.Pulse_Width, anti_clock.Motor_RPM)
plt.xlabel("Pulse Width")
plt.ylabel("Motor_RPM")
# Out:
# Text(0, 0.5, 'Motor_RPM')

# %% [markdown]
# ### Noise Removal
# Denoising the data by using moving average filter with a window size of 4

# %%
def moving_avg(data, win_sz):
    fil = np.zeros((len(data), 1))
    for i in range(len(data)):
        if i < len(data) - win_sz:
            fil[i] = np.mean(data[i:i+win_sz])
        elif i< len(data)-1:
            fil[i] = np.mean(data[i:-1])
        else:
            fil[i] = data[i]
            
    return fil

# %%
y_fil_anti =  moving_avg(anti_clock.Motor_RPM, 3)

#Plots

plt.figure(figsize = (8, 8))
plt.plot(anti_clock.Pulse_Width, y_fil_anti, "--k", linewidth = 2, label = "Filtered")
plt.plot(anti_clock.Pulse_Width, anti_clock.Motor_RPM, "--y", label = "Raw Data")
plt.legend()

# %% [markdown]
# ### Regression model
# Using Least square regression for parameter identification

# %%
def ls(y,A):
    x = np.linalg.inv(A.T @ A) @ A.T @ y
    return x

# %%
def motor_function(x, a, b, c, d, e, f):
    y = a/(b + f * np.exp(c*(x - d))) + e
    return y

# %% [markdown]
# ### Modelling
# Fitting the data to the following function of Pulse Width $$\left[y = \frac{a}{b + ke^{-c(x-d)}} + e\right]$$
# Where:-<br>$y$:- Motor RPM <br> $x$:- Pulse Width <br> $b$:- is constant

# %%
from scipy.optimize import curve_fit

# %%
p0 = [50, 16, 0.05, 1550, -50, 0.05]    #Initial Guess

# %%
ppot, _ = curve_fit(motor_function, anti_clock.Pulse_Width[:, 0], anti_clock.Motor_RPM[:, 0], p0, method="trf")

# %%
[a, b, c, d, e, f] = ppot

# %%
ppot
# Out:
# array([ 5.63790193e+01,  9.67777697e-01,  3.73632001e-02,  1.52052209e+03,
#        -5.21850213e+01,  6.19365921e-01])

# %%
y_pre = np.zeros((len(y_fil_anti), 1))

for i in range(len(y_fil_anti)):
    y_pre[i] = motor_function(anti_clock.Pulse_Width[i], a, b, c, d, e, f)
    

plt.figure(figsize = (8, 8))
plt.plot(anti_clock.Pulse_Width, y_pre)
plt.scatter(anti_clock.Pulse_Width, y_fil_anti, 5*np.ones(len(anti_clock.Pulse_Width)))

# %%
y_pre
# Out:
# array([[  3.37117602],
#        [  3.22033228],
#        [  3.06151764],
#        [  2.89436294],
#        [  2.71848787],
#        [  2.53350127],
#        [  2.33900166],
#        [  2.13457779],
#        [  1.91980935],
#        [  1.69426786],
#        [  1.45751763],
#        [  1.20911692],
#        [  0.9486193 ],
#        [  0.67557512],
#        [  0.38953323],
#        [  0.09004287],
#        [ -0.22334421],
#        [ -0.55107146],
#        [ -0.89357497],
#        [ -1.25128073],
#        [ -1.62460167],
#        [ -2.01393445],
#        [ -2.4196561 ],
#        [ -2.84212042],
#        [ -3.28165424],
#        [ -3.73855346],
#        [ -4.21307906],
#        [ -4.70545291],
#        [ -5.21585358],
#        [ -5.74441208],
#        [ -5.74441208],
#        [ -6.2912077 ],
#        [ -6.85626388],
#        [ -7.43954418],
#        [ -8.04094855],
#        [ -8.66030979],
#        [ -9.29739038],
#        [ -9.95187967],
#        [-10.62339162],
#        [-11.311463  ],
#        [-12.01555222],
#        [-12.7350389 ],
#        [-13.46922398],
#        [-14.2173308 ],
#        [-14.97850679],
#        [-15.75182608],
#        [-16.53629292],
#        [-17.33084584],
#        [-18.13436269],
#        [-18.94566638],
#        [-19.76353132],
#        [-20.58669051],
#        [-21.41384318],
#        [-22.24366284],
#        [-23.07480575],
#        [-23.90591957],
#        [-24.73565213],
#        [-25.56266027],
#        [-26.38561843],
#        [-27.20322712],
#        [-28.01422097],
#        [-28.01422097],
#        [-28.81737635],
#        [-29.61151838],
#        [-30.39552742],
#        [-31.16834473],
#        [-31.92897746],
#        [-32.67650285],
#        [-33.41007155],
#        [-34.12891018],
#        [-34.83232307],
#        [-35.51969321],
#        [-36.19048241],
#        [-36.84423078],
#        [-37.48055555],
#        [-38.09914928],
#        [-38.69977753],
#        [-38.69977753],
#        [-39.28227606],
#        [-39.8465476 ],
#        [-40.39255841],
#        [-40.92033438],
#        [-41.4299571 ],
#        [-41.92155974],
#        [-42.39532281],
#        [-42.85146995],
#        [-43.29026371],
#        [-43.71200141],
#        [-44.11701113],
#        [-44.50564773],
#        [-44.87828915],
#        [-45.23533284],
#        [-45.57719235],
#        [-45.90429415],
#        [-46.21707471],
#        [-46.51597773],
#        [-46.80145164],
#        [-47.07394722],
#        [-47.33391563],
#        [-47.58180638],
#        [-47.81806575],
#        [-48.04313525],
#        [-48.25745026],
#        [-48.46143896],
#        [-48.65552126],
#        [-48.84010801],
#        [-49.01560026],
#        [-49.18238871],
#        [-49.18238871],
#        [-49.34085321],
#        [-49.49136242],
#        [-49.63427354],
#        [-49.76993212],
#        [-49.89867198],
#        [-50.02081515],
#        [-50.1366719 ],
#        [-50.24654081],
#        [-50.35070891],
#        [-50.44945184],
#        [-50.54303403],
#        [-50.63170893],
#        [-50.71571925],
#        [-50.79529727],
#        [-50.87066507],
#        [-50.87066507],
#        [-50.94203485],
#        [-51.00960923],
#        [-51.07358158],
#        [-51.1341363 ],
#        [-51.19144918],
#        [-51.24568766],
#        [-51.29701122],
#        [-51.34557162],
#        [-51.39151325],
#        [-51.43497341],
#        [-51.47608265],
#        [-51.51496499],
#        [-51.55173826],
#        [-51.58651436],
#        [-51.61939951],
#        [-51.65049453],
#        [-51.67989506],
#        [-51.70769186],
#        [-51.73397096],
#        [-51.75881395],
#        [-51.78229817],
#        [-51.80449692],
#        [-51.82547964],
#        [-51.84531213],
#        [-51.86405671],
#        [-51.88177242],
#        [-51.89851513],
#        [-51.91433779],
#        [-51.92929047],
#        [-51.9434206 ],
#        [-51.95677306],
#        [-51.96939031],
#        [-51.98131255],
#        [-51.9925778 ],
#        [-52.00322201],
#        [-52.01327923],
#        [1799.86111111],
#        [1801.38888889],
#        [1802.91666667],
#        [1804.44444444],
#        [1805.97222222],
#        [1807.5       ],
#        [1809.02777778],
#        [1810.55555556],
#        [1812.08333333],
#        [1813.61111111],
#        [1815.13888889],
#        [1816.66666667],
#        [1818.19444444],
#        [1819.72222222],
#        [1821.25      ],
#        [1822.77777778],
#        [1824.30555556],
#        [1825.83333333],
#        [1827.36111111],
#        [1828.88888889],
#        [1830.41666667],
#        [1831.94444444],
#        [1833.47222222],
#        [1835.        ],
#        [1836.52777778],
#        [1838.05555556],
#        [1839.58333333],
#        [1841.11111111],
#        [1842.63888889],
#        [1844.16666667],
#        [1845.69444444],
#        [1847.22222222],
#        [1848.75      ],
#        [1850.27777778],
#        [1851.80555556],
#        [1853.33333333],
#        [1854.86111111],
#        [1856.38888889],
#        [1857.91666667],
#        [1859.44444444],
#        [1860.97222222],
#        [1862.5       ],
#        [1864.02777778],
#        [1865.55555556],
#        [1867.08333333],
#        [1868.61111111],
#        [1870.13888889],
#        [1871.66666667],
#        [1873.19444444],
#        [1874.72222222],
#        [1876.25      ],
#        [1877.77777778],
#        [1879.30555556],
#        [1880.83333333],
#        [1882.36111111],
#        [1883.88888889],
#        [1885.41666667],
#        [1886.94444444],
#        [1888.47222222],
#        [1890.        ],
#        [1891.52777778],
#        [1893.05555556],
#        [1894.58333333],
#        [1896.11111111],
#        [1897.63888889],
#        [1899.16666667],
#        [1900.69444444],
#        [1902.22222222],
#        [1903.75      ],
#        [1905.27777778],
#        [1906.80555556],
#        [1908.33333333],
#        [1909.86111111],
#        [1911.38888889],
#        [1912.91666667],
#        [1914.44444444],
#        [1915.97222222],
#        [1917.5       ],
#        [1919.02777778],
#        [1920.55555556],
#        [1922.08333333],
#        [1923.61111111],
#        [1925.13888889],
#        [1926.66666667],
#        [1928.19444444],
#        [1929.72222222],
#        [1931.25      ],
#        [1932.77777778],
#        [1934.30555556],
#        [1935.83333333],
#        [1937.36111111],
#        [1938.88888889],
#        [1940.41666667],
#        [1941.94444444],
#        [1943.47222222],
#        [1945.        ],
#        [1946.52777778],
#        [1948.05555556],
#        [1949.58333333],
#        [1951.11111111],
#        [1952.63888889],
#        [1954.16666667],
#        [1954.16666667],
#        [1955.69444444],
#        [1957.22222222],
#        [1958.75      ],
#        [1960.27777778],
#        [1961.80555556],
#        [1963.33333333],
#        [1963.33333333],
#        [1964.86111111],
#        [1966.38888889],
#        [1967.91666667],
#        [1967.91666667],
#        [1969.44444444],
#        [1970.97222222],
#        [1972.5       ],
#        [1974.02777778],
#        [1975.55555556],
#        [1977.08333333],
#        [1977.08333333],
#        [1978.61111111],
#        [1980.13888889],
#        [1981.66666667],
#        [1981.66666667],
#        [1983.19444444],
#        [1984.72222222],
#        [1986.25      ],
#        [1987.77777778],
#        [1989.30555556],
#        [1990.83333333],
#        [1992.36111111],
#        [1993.88888889],
#        [1995.41666667],
#        [1995.41666667],
#        [1996.94444444],
#        [1998.47222222]])

# %%
skm.mean_squared_error(anti_clock.Motor_RPM, y_pre)
# Out:
# 2.429983820565853

# %% [markdown]
# Thus we get the follwing function of the continuous DC servo motor for anti-clockwise rotation
# $$\left[y = \frac{56.3790193}{0.967777697 + 0.619365921 * e^{0.0373632001(x - 1520.52209)}} - 52.1850213 \right]$$
# Where, <br>
# $y:-$ Motor RPM <br>
# $x:-$ Pulse Width

# %% [markdown]
# ### Clockwise Rotation data of the Motor

# %%
plt.plot(clock.Pulse_Width, clock.Motor_RPM)
plt.xlabel("Pulse Width")
plt.ylabel("Motor RPM")
# Out:
# Text(0, 0.5, 'Motor RPM')

# %% [markdown]
# #### Noise Removal(Not Required)
# Denoising the data by using moving average filter with a window size of 3

# %%
y_clock_fil = moving_avg(clock.Motor_RPM, 3)

plt.figure(figsize = (8, 8))
plt.plot(clock.Pulse_Width, y_clock_fil, "--k", linewidth = 2)
plt.plot(clock.Pulse_Width, clock.Motor_RPM, "--y")

# %% [markdown]
# ## Clockwise Rotation
# Here we will assume a similar function as above to which we will fit the data.
# $$y = \frac{a}{b + ke^{-c(x - d)}} + e$$

# %%
p0_2 = [30, 3, 0.02, 1250, 30, 1] #initial guess

# %%
ppot2, _ = curve_fit(motor_function, clock.Pulse_Width[:, 0], clock.Motor_RPM[:, 0], p0_2, method="trf")

# %%
ppot2
# Out:
# array([ 2.73891196e+01,  5.20407706e-01,  4.01892023e-02,  1.24324129e+03,
#        -2.25294765e+00,  1.85094337e-02])

# %%
[a_c, b_c, c_c, d_c, e_c, f_c] = ppot2

# %%
y_pre_2 = np.zeros((len(clock.Motor_RPM), 1))

for i in range(len(y_pre_2)):
    y_pre_2[i] = motor_function(clock.Pulse_Width[i], a_c, b_c, c_c, d_c, e_c, f_c)
    

plt.figure(figsize = (8, 8))
plt.plot(clock.Pulse_Width, y_pre_2)
plt.plot(clock.Pulse_Width, y_clock_fil)
plt.scatter(clock.Pulse_Width, clock.Motor_RPM, 5*np.ones(len(clock.Pulse_Width)))

# %%
skm.mean_squared_error(clock.Motor_RPM, y_pre_2)
# Out:
# 2.8863852286922405

# %% [markdown]
# Thus we get the following function for clockwise rotation of continuous DC Servo Motor
# $$y = \left[\frac{-52.5881734}{1 + e^{-0.0402144660(x - 1325.03527)}} + 50.3756412 \right]$$

# %% [markdown]
# 2) Without Using in-built functions

# %%
# variables
b_anti = 1
c_anti = 0.032
d_anti = 1520.5221

# %%
# function to create matrix

def matrix_anti(PWM, b, c, d):
    A = np.zeros([len(PWM),2])
    
    for i in range(len(PWM)):
        A[i, 0] = 1/(b + np.exp(c*(PWM[i] - d)))
        A[i, 1] = 1
        
    return A

# %%
A_anti = matrix_anti(anti_clock.Pulse_Width, b_anti, c_anti, d_anti)
x_anti = ls(anti_clock.Motor_RPM, A_anti)

# %%
a_anti = x_anti[0]
e_anti = x_anti[1]

# %%
x_anti
# Out:
# array([[ 65.85037723],
#        [-52.12739188]])

# %%
def anti_clock_model(PWM, a, b, c, d, e):
    y = np.zeros(PWM.shape)
    
    for i in range(len(PWM)):
        y[i] = a/(b + np.exp(c*(PWM[i] - d))) + e
        
    return y

# %%
y_pred_anti = anti_clock_model(anti_clock.Pulse_Width, a_anti, b_anti, c_anti, d_anti, e_anti)

# %%
plt.plot(anti_clock.Pulse_Width, y_pred_anti)
plt.plot(anti_clock.Pulse_Width, anti_clock.Motor_RPM)

# %%
skm.mean_squared_error(anti_clock.Motor_RPM, y_pred_anti)
# Out:
# 3.4291556793726325
